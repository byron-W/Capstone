# %%
import matplotlib.pyplot as plt
import numpy as np
import imageio.v3 as img

url = 'actual_vs_predicted_weather.png'
amg = img.imread('actual_vs_predicted_weather.png', mode='F').astype(np.uint8)
bmg = img.imread('weather_scatterplots.png', mode='F').astype(np.uint8)

plt.imshow(amg, cmap='grey')
plt.show()
plt.imshow(bmg, cmap='grey')
plt.show()

# %%
temp = img.imread('boxplot_temperature.png', mode='F').astype(np.uint8)
precip = img.imread('boxplot_precip.png', mode='F').astype(np.uint8)
wind = img.imread('boxplot_wind.png', mode='F').astype(np.uint8)

plt.imshow(temp, cmap='grey')
plt.axis('off')
plt.grid(False)
plt.show()
